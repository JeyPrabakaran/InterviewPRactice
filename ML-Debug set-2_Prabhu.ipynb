# %%
#1.Why does this train-test split fail?
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.2, random_state=42)

Answer:
test_size should be 20 or 30 percentage of original dataset. Here test_size is 1.2 so nothiing will  be there for training.

# %%
#2.
from sklearn.tree import DecisionTreeClassifier

X = [[1, 2], [3, 4], [5, 6]]
y = [0, 1, 0]

model = DecisionTreeClassifier(max_depth=100)
model.fit(X, y)
print(model.score(X, y))
# Out:
# 1.0

# %%
#corrected code
from sklearn.tree import DecisionTreeClassifier

X = [[1, 2], [3, 4], [5, 6]]
y = [0, 1, 0]

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.5,random_state=0)


#model = DecisionTreeClassifier(max_depth=100)
model = DecisionTreeClassifier(max_depth=2)
model.fit(X, y)
y_pred=model.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

print('R2_score is:',r_score)
print('Test score:',model.score(X_test,y_test))
# Out:
# R2_score is: 1.0
# Test score: 1.0

# %%
#3.
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2], [3, 4], [5, 6]])

model = KMeans(n_clusters=5)
model.fit(X)
# Out:
# C:\Users\Prabhu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
#corrected code
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2], [3, 4], [5, 6]])

model = KMeans(n_clusters=2)#number of clusters should be lesser or equal to data points
model.fit(X)
# Out:
# C:\Users\Prabhu\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
#4.
import padas as pd  

df = pd.DataFrame({'A': [1, 2, 3]})
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 #4.
# ----> 2 import padas as pd
#       4 df = pd.DataFrame({'A': [1, 2, 3]})
#       5 print(df)
#
# ModuleNotFoundError: No module named 'padas'

# %%
#corrected code
import pandas as pd  #Pandas type error corrected

df = pd.DataFrame({'A': [1, 2, 3]})
print(df)
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
#5.from sklearn.tree import DecisionTreClassifier  # Typo in 'DecisionTreeClassifier'

from sklearn.tree import DecisionTreClassifier  # Typo in 'DecisionTreeClassifier'

model = DecisionTreClassifier()

# %%
#corrected code
from sklearn.tree import DecisionTreeClassifier  # Typo error corrected

model = DecisionTreeClassifier()

# %%
#6.
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(depth=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 #6.
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 4 model = DecisionTreeClassifier(depth=3)
#
# TypeError: DecisionTreeClassifier.__init__() got an unexpected keyword argument 'depth'

# %%
#corrected code
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=3)  #argument name corrected

# %%
#7.
from sklearn.linear_model import LinearRegression

X = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]

model = LinearRegression()
model.fit(X, y)

print(model.coef)  # Incorrect attribute name

# %%
#corrected code
from sklearn.linear_model import LinearRegression

X = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]

model = LinearRegression()
model.fit(X, y)

print(model.coef_[0])  # attribute name corrected
# Out:
# 2.000000000000001

# %%
#8.
from sklearn.neighbors import KNeighborsClassifier

X_train = [[1, 2], [3, 4], [5, 6]]
y_train = [0, 1, 0]

model = KNeighborsClassifier(n_neighbors=0)  # Invalid value for n_neighbors
model.fit(X_train, y_train)

# %%
from sklearn.neighbors import KNeighborsClassifier

X_train = [[1, 2], [3, 4], [5, 6]]
y_train = [0, 1, 0]

model = KNeighborsClassifier(n_neighbors=2)  #  value for n_neighbors should be a positive integer and lesser than or rqual to training samples
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#9.
import pandas as pd

df = pd.DataFrame({'A': [10, 20, 30], 'B': [1, 2, 3]})
print(df.iloc['A'])  # Incorrect: iloc requires integer indexes

# %%
#corrected code
import pandas as pd

df = pd.DataFrame({'A': [10, 20, 30], 'B': [1, 2, 3]})
print(df.loc[:,'A']) 
print(df.iloc[:,0])#  iloc requires integer indexes
# Out:
# 0    10
# 1    20
# 2    30
# Name: A, dtype: int64
# 0    10
# 1    20
# 2    30
# Name: A, dtype: int64

# %%
#10.
from sklearn.ensemble import RandomForestClassifier

X_train = [[1, 2], [3, 4], [5, 6]]
y_train = [0, 1, 0]

model = RandomForestClassifier()
model.fit(X_train, y_train)

probs = model.predict_proba([[2, 3]])[1]  # Incorrect index
print(probs)

# %%
#corrected code
from sklearn.ensemble import RandomForestClassifier

X_train = [[1, 2], [3, 4], [5, 6]]
y_train = [0, 1, 0]

model = RandomForestClassifier()
model.fit(X_train, y_train)

probs = model.predict_proba([[2, 3]])[0] # Incorrect index corrected
print(probs)
# Out:
# [0.72 0.28]
